# %% [markdown]
# <a href="https://colab.research.google.com/github/jiayuankeliang/309CourseWork2/blob/main/download_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.Adding google drive

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 2. enter to the Google Drive folder you want to save

# %%
# %cd drive/MyDrive/data
# Out:
# /content/drive/MyDrive/data

# %% [markdown]
# 3. install kaggle module

# %%
# !pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# 4.upload your kaggle.json file

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-5d6ce427-81c6-4f29-948e-646337a5e686" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5d6ce427-81c6-4f29-948e-646337a5e686">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 5.copy kaggle.json to your root floder and modify the permission

# %%
# !mkdir -p ~/.kaggle 
# !cp kaggle.json ~/.kaggle/ 
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# 6.download data by kaggle api command

# %%
# !kaggle datasets download -d meowmeowmeowmeowmeow/gtsrb-german-traffic-sign
# Out:
# ...
# 100% 612M/612M [00:04<00:00, 163MB/s]
# 100% 612M/612M [00:04<00:00, 129MB/s]

# %% [markdown]
# 7.unzip .zip file, It takes about 10 minutes

# %%
# !unzip gtsrb-german-traffic-sign.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Test/09012.png
#   inflating: Test/09013.png
#   inflating: Test/09014.png
#   inflating: Test/09015.png
#   inflating: Test/09016.png
#   inflating: Test/09017.png
#   inflating: Test/09018.png
#   inflating: Test/09019.png
#   inflating: Test/09020.png
#   inflating: Test/09021.png
#   inflating: Test/09022.png
#   inflating: Test/09023.png
#   inflating: Test/09024.png
#   inflating: Test/09025.png
#   inflating: Test/09026.png
#   inflating: Test/09027.png
#   inflating: Test/09028.png
#   inflating: Test/09029.png
#   inflating: Test/09030.png
#   inflating: Test/09031.png
#   inflating: Test/09032.png
#   inflating: Test/09033.png
#   inflating: Test/09034.png
#   inflating: Test/09035.png
#   inflating: Test/09036.png
#   inflating: Test/09037.png
#   inflating: Test/09038.png
#   inflating: Test/09039.png
#   inflating: Test/09040.png
#   inflating: Test/09041.png
#   inflating: Test/09042.png
# ...
